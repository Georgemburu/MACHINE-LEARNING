# %%
import numpy as np;

# %%
weights = np.array([0.7,0.2,-0.3]);
alpha = 0.01;
streetlights = np.array([[0,0,1],
                         [0,1,1],
                         [0,0,1],
                         [1,1,1],
                         [0,1,1],
                         [1,0,1]
                        ]);
walk_vs_stop = np.array([ 0,1,0,1,1,0]);

# %%
for i in range(40):
    error_for_all_lights = 0;
    for row_index in range(len(streetlights)):
        input = streetlights[row_index];
        goal_prediction = walk_vs_stop[row_index];
        
        prediction = input.dot(weights);
        error = (prediction - goal_prediction) ** 2;
        
        error_for_all_lights += error;
        delta = prediction - goal_prediction;
        weights = weights - (alpha * (input * delta));
        
        print('prediction:' + str(prediction));
        if(i==39):
            if(prediction>=0.7):
                print('Prediction: WALK')
            elif(prediction<0.7):
                print('Prediction: STOP')
        
    print('weights:'+ str(weights));
    print('Error:' + str(error))
# Out:
# prediction:-0.3
# prediction:-0.09699999999999998
# prediction:-0.28603
# prediction:0.6278002999999999
# prediction:-0.06475570600000002
# prediction:0.43492185105999986
# weights:[ 0.69937278  0.22533955 -0.27314936]
# Error:0.1891570165294567
# prediction:-0.27314936445060006
# prediction:-0.045078316746094055
# prediction:-0.25996708763863313
# prediction:0.6777956989546141
# prediction:-0.01513299351387809
# prediction:0.4586007776831996
# weights:[ 0.69800881  0.24916371 -0.24858005]
# Error:0.21031467329163547
# prediction:-0.24858005159348612
# prediction:0.0030694590955023526
# prediction:-0.23612494566850628
# prediction:0.723378133093299
# prediction:0.03090175670841136
# prediction:0.47946853728225036
# weights:[ 0.69598035  0.27159022 -0.22610118]
# Error:0.2298900782435807
# prediction:-0.22610118048266084
# prediction:0.047750048006247214
# prediction:-0.2143176691578967
# prediction:0.7649185707569675
# prediction:0.07363985232256193
# prediction:0.4977710846145835
# weights:[ 0.69335345  0.29272713 -0.20553779]
# Error:0.24777605267837888
# prediction:-0.20553778754325888
# prediction:0.08924472230539746
# prediction:-0.19437485689088027
# prediction:0.8027570268937492
# prediction:0.11334843589032331
# prediction:0.5137337172468011
# weights:[ 0.69018854  0.31267363 -0.1867295 ]
# Error:0.26392233223621614
# prediction:-0.18672950012228018
# prediction:0.12781142500127163
# prediction:-0.1761403193710701
# prediction:0.8372051427191021
# prediction:0.15027249684057484
# prediction:0.527562799023998
# weights:[ 0.68654086  0.33152074 -0.16952932]
# Error:0.2783225069140354
# prediction:-0.16952932056319614
# prediction:0.16368671211915534
# prediction:-0.15947089447875573
# prediction:0.8685485504282741
# prediction:0.1846367158129943
# prediction:0.5394473399060508
# weights:[ 0.6824609   0.34935202 -0.15380251]
# Error:0.2910034325317143
# prediction:-0.15380251159544137
# prediction:0.1970875332136283
# prediction:-0.14423536181162325
# prediction:0.897049040870843
# prediction:0.21664715535005508
# prediction:0.5495604441389467
# weights:[ 0.67799481  0.36624418 -0.13942557]
# Error:0.3020166817621963
# prediction:-0.13942557459710544
# prediction:0.22821286354763554
# prediction:-0.13031344748661075
# prediction:0.9229465506048222
# prediction:0.24649280973945245
# prediction:0.5580606377320376
# weights:[ 0.67318474  0.38226766 -0.12628531]
# Error:0.3114316753858885
# prediction:-0.12628531299250775
# prediction:0.25724520029726816
# prediction:-0.11759491186555536
# prediction:0.946460983379883
# prediction:0.2743470257423807
# prediction:0.5650930852979834
# weights:[ 0.6680692   0.39748713 -0.11427797]
# Error:0.31933019505159393
# prediction:-0.11427797369110228
# prediction:0.28435193411146426
# prediction:-0.10597871329530589
# prediction:0.9677938798453141
# prediction:0.30036880496528173
# prediction:0.5707907054742141
# weights:[ 0.66268335  0.41196198 -0.10330846]
# Error:0.325802029455751
# prediction:-0.10330846006520093
# prediction:0.30968660641188595
# prediction:-0.09537224152866779
# prediction:0.9871299481288658
# prediction:0.3247039977363576
# prediction:0.5752751933766088
# weights:[ 0.6570593   0.42574678 -0.09328961]
# Error:0.33094154811449467
# prediction:-0.09328961050579943
# prediction:0.33339006195292237
# prediction:-0.08569061502027066
# prediction:1.0046384668789428
# prediction:0.3474863975264878
# prediction:0.5786579578319643
# weights:[ 0.65122634  0.43889163 -0.08414154]
# Error:0.33484503216225936
# prediction:-0.0841415370924419
# prediction:0.3555915053685629
# prediction:-0.07685603677520311
# prediction:1.0204745713967105
# prediction:0.3688387442010094
# prediction:0.5810409804903716
# weights:[ 0.64521118  0.45144258 -0.07579102]
# Error:0.33760862100921235
# prediction:-0.07579101936833199
# prediction:0.37640946970576883
# prediction:-0.06879720387170636
# prediction:1.0347804325992667
# prediction:0.3888736436983852
# prediction:0.5825176033269375
# weights:[ 0.6390382   0.46344194 -0.06817095]
# Error:0.33932675818575925
# prediction:-0.0681709486292352
# prediction:0.39595270427744045
# prediction:-0.06144876618571725
# prediction:1.047686337743383
# prediction:0.40769441109888116
# prediction:0.5831732504999174
# weights:[ 0.6327296   0.47492861 -0.06121982]
# Error:0.34009104009863944
# prediction:-0.06121981851728189
# prediction:0.41432098855707716
# prediction:-0.05475083021767985
# prediction:1.0593116810953134
# prediction:0.4253958434662062
# prediction:0.5830860900351297
# weights:[ 0.62630563  0.48593832 -0.05488126]
# Error:0.33998938839245535
# prediction:-0.05488125806146954
# prediction:0.4316058782771454
# prediction:-0.0486485042636263
# prediction:1.0697658720501355
# prediction:0.44206492831323607
# prediction:0.5823276403507716
# weights:[ 0.61978469  0.49650396 -0.0491036 ]
# Error:0.33910548071649754
# prediction:-0.049103603628131466
# prediction:0.44789138937974493
# prediction:-0.043091481485647606
# prediction:1.0791491675788942
# prediction:0.4577814930554286
# prediction:0.5809633262189643
# weights:[ 0.61318357  0.50665574 -0.04383951]
# Error:0.33751838641140275
# prediction:-0.043839506539324
# prediction:0.46325462499752357
# prediction:-0.038033657723905996
# prediction:1.087553435308721
# prediction:0.4726188003686378
# prediction:0.5790529883773813
# weights:[ 0.6065175   0.51642147 -0.03904557]
# Error:0.33530236334877567
# prediction:-0.03904557338721434
# prediction:0.4777663502113634
# prediction:-0.03343278115545583
# prediction:1.0950628530157385
# prediction:0.48664409395837593
# prediction:0.5766513506532482
# weights:[ 0.59980036  0.52582673 -0.03468204]
# Error:0.3325267802102155
# prediction:-0.0346820363201749
# prediction:0.49149151893587767
# prediction:-0.029250131146331924
# prediction:1.1017545498289816
# prediction:0.4999190988720438
# prediction:0.5738084481401895
# weights:[ 0.59304473  0.53489508 -0.03071245]
# Error:0.32925613515705254
# prediction:-0.030712450803280753
# prediction:0.5044897569212338
# prediction:-0.025450223864460282
# prediction:1.1076991940021204
# prediction:0.5125004801414113
# prediction:0.5705700196733943
# weights:[ 0.58626204  0.54364819 -0.02710342]
# Error:0.3255501473500975
# prediction:-0.027103418563984936
# prediction:0.516815804527489
# prediction:-0.022000542423619974
# prediction:1.112961531705087
# prediction:0.5244402632270736
# prediction:0.5669778675781552
# weights:[ 0.57946264  0.55210601 -0.02382433]
# Error:0.32146390232347205
# prediction:-0.02382433362448693
# prediction:0.5285199226229954
# prediction:-0.018871289514472016
# prediction:1.1176008809167592
# prediction:0.5357862194473451
# prediction:0.563070187418943
# weights:[ 0.57265593  0.56028694 -0.02084715]
# Error:0.3170480359600036
# prediction:-0.020847149497157772
# prediction:0.5396482646791804
# prediction:-0.016035160648977996
# prediction:1.1216715841598084
# prediction:0.5465822193088904
# prediction:0.5588818702489486
# weights:[ 0.5658504   0.56820792 -0.01814617]
# Error:0.31234894489296267
# prediction:-0.018146165779664686
# prediction:0.5502432178780198
# prediction:-0.013467136300648237
# prediction:1.1252234235071001
# prediction:0.5568685564133238
# prediction:0.5544447796517172
# weights:[ 0.55905372  0.57588457 -0.01569783]
# Error:0.3074090136830413
# prediction:-0.015697832533363168
# prediction:0.5603437158138738
# prediction:-0.011144291366168273
# prediction:1.128302001003304
# prediction:0.566682244391192
# prediction:0.5497880056755615
# weights:[ 0.55227282  0.58333129 -0.01348057]
# Error:0.30226685118471125
# prediction:-0.013480570963207164
# prediction:0.5699855251562446
# prediction:-0.009045620505137537
# prediction:1.1309490873834283
# prediction:0.5760572891105026
# prediction:0.5449380975863977
# weights:[ 0.54551394  0.59056137 -0.01147461]
# Error:0.2969575302010823
# prediction:-0.011474609040889445
# prediction:0.5792015084428375
# prediction:-0.007151878034908925
# prediction:1.1332029417298888
# prediction:0.585024938219732
# prediction:0.5399192772042042
# weights:[ 0.53878272  0.59758708 -0.00966183]
# Error:0.2915128258967103
# prediction:-0.009661830826098085
# prediction:0.5880218649915562
# prediction:-0.0054454311677526665
# prediction:1.1350986044896207
# prediction:0.5936139099136101
# prediction:0.5347536344412145
# weights:[ 0.5320842   0.60441973 -0.00802564]
# Error:0.28596144954808805
# prediction:-0.008025638344519593
# prediction:0.5964743517543709
# prediction:-0.003910125478618106
# prediction:1.1366681660709794
# prediction:0.6018506026526501
# prediction:0.5294613065251319
# weights:[ 0.52542291  0.6110698  -0.00655082]
# Error:0.28032927510729966
# prediction:-0.006550824976319539
# prediction:0.604584485784109
# prediction:-0.0025311615843974337
# prediction:1.1379410130552194
# prediction:0.6097592874231664
# prediction:0.5240606422670592
# weights:[ 0.51880289  0.61754695 -0.00522346]
# Error:0.27463955677336255
# prediction:-0.00522345939600791
# prediction:0.6123757298459925
# prediction:-0.0012949821005077563
# prediction:1.1389440538878037
# prediction:0.6173622839923216
# prediction:0.518568352620544
# weights:[ 0.51222776  0.62386013 -0.00403078]
# Error:0.26891313633958486
# prediction:-0.004030779184509372
# prediction:0.6198696625781149
# prediction:-0.00018916801844542789
# prediction:1.1397019257593797
# prediction:0.6246801224915494
# prediction:0.5129996486742784
# weights:[ 0.50570075  0.63001762 -0.00296109]
# Error:0.2631686395399331
# prediction:-0.0029610933075130473
# prediction:0.6270861344880507
# prediction:0.000797656280681576
# prediction:1.1402371842437888
# prediction:0.6317316915506072
# prediction:0.5073683681257988
# weights:[ 0.49922469  0.63602707 -0.00200369]
# Error:0.25742266097463606
# prediction:-0.002003692721327188
# prediction:0.6340434109655503
# prediction:0.0016759100962305813
# prediction:1.1405704771298872
# prediction:0.6385343741026793
# prediction:0.5016870911962538
# weights:[ 0.49280212  0.64189558 -0.00114877]
# Error:0.25168993747295826
# prediction:-0.0011487684290199282
# prediction:0.6407583033929534
# prediction:0.0024551362213407375
# prediction:1.1407207037642295
# prediction:0.6451041718875963
# prediction:0.49596724686631544
# weights:[ 4.86435238e-01  6.47629752e-01 -3.87336366e-04]
# Error:0.2459835099641527
# prediction:-0.0003873363660540823
# prediction:0.6472462893448417
# prediction:0.003144074104158041
# prediction:1.1407051611119465
# prediction:0.6514558195946645
# prediction:0.49021921023997406
# weights:[4.80125995e-01 6.53235680e-01 2.88831454e-04]
# Error:0.24031487408830388
# prediction:0.0002888314536506108
# Prediction: STOP
# prediction:0.6535216227858349
# Prediction: STOP
# prediction:0.0037507269112557555
# Prediction: STOP
# prediction:1.1405396776425296
# Prediction: WALK
# prediction:0.6576028895081552
# Prediction: STOP
# prediction:0.484452391775735
# Prediction: STOP
# weights:[0.47387607 0.65871904 0.00088727]
# Error:0.23469411989723024

# %%
##prediction
# 0,1,0,1,1,0
