# %%
import keras
from keras.layers import Input, Embedding, LSTM, Dense
from keras.models import Model
import numpy as np
np.random.seed(0) #set random seed for reproducibility

#Headline input: meant to receive sequences of 100 intergers, between
#1 and 10000
#Note that we can name any layer by passing it a 'name' argument
main_input = Input(shape=(100,), dtype='int32', name='main_input')

# This embedding layer will encode the input sequence
#into a sequence of dense 512-dimension vectors
x = Embedding(output_dim=512, input_dim=10000, input_length=100)(main_input)

# A LSTM will transform the vector sequence into a single vector,
#containing information about the entire sequence
lstm_out = LSTM(32)(x)

#auxillary loss
auxiliary_output = Dense(1, activation='sigmoid', name='aux_output')(lstm_out)

# feed into the model our auxiliary input data by concaenating
# it with the LSTM output
auxiliary_input = Input(shape=(5,), name='aux_input')
x = keras.layers.concatenate([lstm_out, auxiliary_input])
# We stack a deep densely-connected network on top
x = Dense(64, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dense(64, activation='relu')(x)

# And finally we add the  main logistic regression layer
main_output = Dense(1, activation='sigmoid', name='main_output')(x)

# DEFINE THE MODEL
## defines the model with two inputs and two outputs
model = Model(
    inputs=[main_input, auxiliary_input], 
    outputs=[main_output,auxiliary_output]
)

# COMPILE
model.compile(
    optimizer='rmsprop',
    loss='binary_crossentropy',
    loss_weights =[1.,0.2]
             )
#print the model summary
print(model.summary())

# TRAIN -> passing a list of input arrays and target arrays
headline_data = np.round(np.abs(np.random.rand(12,100)*100))
additional_data = np.random.randn(12,5)
headline_labels = np.random.randn(12,1)
additional_labels = np.random.randn(12,1)
model.fit(
    [headline_data, additional_data],
    [headline_labels, additional_labels],
    epochs=50,
    batch_size=32)
# Out:
# WARNING:tensorflow:From /home/george/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 100)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 100, 512)     5120000     main_input[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 32)           69760       embedding_3[0][0]
# __________________________________________________________________________________________________
# aux_input (InputLayer)          (None, 5)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 37)           0           lstm_3[0][0]
#                                                                  aux_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           2432        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           4160        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           4160        dense_2[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            65          dense_3[0][0]
# __________________________________________________________________________________________________
# aux_output (Dense)              (None, 1)            33          lstm_3[0][0]
# ==================================================================================================
# Total params: 5,200,610
# Trainable params: 5,200,610
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /home/george/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 12/12 [==============================] - 13s 1s/step - loss: 0.8157 - main_output_loss: 0.6776 - aux_output_loss: 0.6905
# Epoch 2/50
# 12/12 [==============================] - 1s 59ms/step - loss: 0.7060 - main_output_loss: 0.5894 - aux_output_loss: 0.5831
# Epoch 3/50
# 12/12 [==============================] - 1s 58ms/step - loss: 0.6231 - main_output_loss: 0.5259 - aux_output_loss: 0.4860
# Epoch 4/50
# 12/12 [==============================] - 1s 44ms/step - loss: 0.5452 - main_output_loss: 0.4708 - aux_output_loss: 0.3721
# Epoch 5/50
# 12/12 [==============================] - 1s 49ms/step - loss: 0.4606 - main_output_loss: 0.4144 - aux_output_loss: 0.2310
# Epoch 6/50
# 12/12 [==============================] - 1s 44ms/step - loss: 0.3576 - main_output_loss: 0.3476 - aux_output_loss: 0.0500
# Epoch 7/50
# 12/12 [==============================] - 1s 44ms/step - loss: 0.2395 - main_output_loss: 0.2746 - aux_output_loss: -0.1755
# Epoch 8/50
# 12/12 [==============================] - 1s 66ms/step - loss: 0.0920 - main_output_loss: 0.1822 - aux_output_loss: -0.4507
# Epoch 9/50
# 12/12 [==============================] - 1s 43ms/step - loss: -0.0924 - main_output_loss: 0.0596 - aux_output_loss: -0.7602
# Epoch 10/50
# 12/12 [==============================] - 1s 47ms/step - loss: -0.2794 - main_output_loss: -0.0819 - aux_output_loss: -0.9876
# Epoch 11/50
# 12/12 [==============================] - 1s 52ms/step - loss: -0.4464 - main_output_loss: -0.2307 - aux_output_loss: -1.0788
# Epoch 12/50
# 12/12 [==============================] - 1s 51ms/step - loss: -0.6077 - main_output_loss: -0.3625 - aux_output_loss: -1.2258
# Epoch 13/50
# 12/12 [==============================] - 1s 48ms/step - loss: -0.8364 - main_output_loss: -0.5791 - aux_output_loss: -1.2861
# Epoch 14/50
# 12/12 [==============================] - 1s 54ms/step - loss: -1.0445 - main_output_loss: -0.7622 - aux_output_loss: -1.4114
# Epoch 15/50
# 12/12 [==============================] - 1s 60ms/step - loss: -1.2807 - main_output_loss: -0.9981 - aux_output_loss: -1.4132
# Epoch 16/50
# 12/12 [==============================] - 1s 48ms/step - loss: -1.5405 - main_output_loss: -1.2371 - aux_output_loss: -1.5172
# Epoch 17/50
# 12/12 [==============================] - 1s 56ms/step - loss: -1.8421 - main_output_loss: -1.5406 - aux_output_loss: -1.5076
# Epoch 18/50
# 12/12 [==============================] - 1s 47ms/step - loss: -2.2222 - main_output_loss: -1.8923 - aux_output_loss: -1.6493
# Epoch 19/50
# 12/12 [==============================] - 0s 41ms/step - loss: -2.6382 - main_output_loss: -2.3163 - aux_output_loss: -1.6097
# Epoch 20/50
# 12/12 [==============================] - 1s 59ms/step - loss: -3.0494 - main_output_loss: -2.7042 - aux_output_loss: -1.7261
# Epoch 21/50
# 12/12 [==============================] - 1s 82ms/step - loss: -3.5977 - main_output_loss: -3.2755 - aux_output_loss: -1.6107
# Epoch 22/50
# 12/12 [==============================] - 1s 73ms/step - loss: -4.1781 - main_output_loss: -3.8299 - aux_output_loss: -1.7414
# Epoch 23/50
# 12/12 [==============================] - 1s 46ms/step - loss: -4.8331 - main_output_loss: -4.5103 - aux_output_loss: -1.6136
# Epoch 24/50
# 12/12 [==============================] - 1s 44ms/step - loss: -5.5533 - main_output_loss: -5.2145 - aux_output_loss: -1.6939
# Epoch 25/50
# 12/12 [==============================] - 1s 52ms/step - loss: -6.3413 - main_output_loss: -6.0287 - aux_output_loss: -1.5629
# Epoch 26/50
# 12/12 [==============================] - 1s 49ms/step - loss: -7.1382 - main_output_loss: -6.8032 - aux_output_loss: -1.6753
# Epoch 27/50
# 12/12 [==============================] - 1s 44ms/step - loss: -7.9946 - main_output_loss: -7.7045 - aux_output_loss: -1.4503
# Epoch 28/50
# 12/12 [==============================] - 1s 52ms/step - loss: -8.3876 - main_output_loss: -8.0174 - aux_output_loss: -1.8511
# Epoch 29/50
# 12/12 [==============================] - 1s 56ms/step - loss: -9.8066 - main_output_loss: -9.5087 - aux_output_loss: -1.4899
# Epoch 30/50
# 12/12 [==============================] - 1s 54ms/step - loss: -11.0033 - main_output_loss: -10.7067 - aux_output_loss: -1.4831
# Epoch 31/50
# 12/12 [==============================] - 1s 55ms/step - loss: -12.2005 - main_output_loss: -11.9086 - aux_output_loss: -1.4599
# Epoch 32/50
# 12/12 [==============================] - 1s 54ms/step - loss: -13.4613 - main_output_loss: -13.1744 - aux_output_loss: -1.4347
# Epoch 33/50
# 12/12 [==============================] - 1s 52ms/step - loss: -14.7942 - main_output_loss: -14.5135 - aux_output_loss: -1.4033
# Epoch 34/50
# 12/12 [==============================] - 1s 70ms/step - loss: -16.2007 - main_output_loss: -15.9245 - aux_output_loss: -1.3808
# Epoch 35/50
# 12/12 [==============================] - 1s 46ms/step - loss: -17.6527 - main_output_loss: -17.3827 - aux_output_loss: -1.3501
# Epoch 36/50
# 12/12 [==============================] - 1s 54ms/step - loss: -19.0507 - main_output_loss: -18.7790 - aux_output_loss: -1.3587
# Epoch 37/50
# 12/12 [==============================] - 1s 44ms/step - loss: -20.8171 - main_output_loss: -20.5550 - aux_output_loss: -1.3103
# Epoch 38/50
# 12/12 [==============================] - 1s 50ms/step - loss: -22.5253 - main_output_loss: -22.2653 - aux_output_loss: -1.2999
# Epoch 39/50
# 12/12 [==============================] - 1s 55ms/step - loss: -24.1538 - main_output_loss: -23.8940 - aux_output_loss: -1.2992
# Epoch 40/50
# 12/12 [==============================] - 1s 46ms/step - loss: -25.4993 - main_output_loss: -25.2159 - aux_output_loss: -1.4171
# Epoch 41/50
# 12/12 [==============================] - 1s 46ms/step - loss: -27.7419 - main_output_loss: -27.4852 - aux_output_loss: -1.2835
# Epoch 42/50
# 12/12 [==============================] - 1s 46ms/step - loss: -29.7909 - main_output_loss: -29.5307 - aux_output_loss: -1.3013
# Epoch 43/50
# 12/12 [==============================] - 1s 100ms/step - loss: -31.8421 - main_output_loss: -31.5807 - aux_output_loss: -1.3073
# Epoch 44/50
# 12/12 [==============================] - 1s 95ms/step - loss: -33.9501 - main_output_loss: -33.6858 - aux_output_loss: -1.3217
# Epoch 45/50
# 12/12 [==============================] - 1s 42ms/step - loss: -36.0737 - main_output_loss: -35.8107 - aux_output_loss: -1.3151
# Epoch 46/50
# 12/12 [==============================] - 0s 41ms/step - loss: -38.3634 - main_output_loss: -38.0954 - aux_output_loss: -1.3396
# Epoch 47/50
# 12/12 [==============================] - 0s 41ms/step - loss: -40.5956 - main_output_loss: -40.3298 - aux_output_loss: -1.3286
# Epoch 48/50
# 12/12 [==============================] - 1s 42ms/step - loss: -43.1954 - main_output_loss: -42.9232 - aux_output_loss: -1.3611
# Epoch 49/50
# 12/12 [==============================] - 0s 41ms/step - loss: -45.5874 - main_output_loss: -45.3170 - aux_output_loss: -1.3523
# Epoch 50/50
# 12/12 [==============================] - 1s 43ms/step - loss: -48.2598 - main_output_loss: -47.9838 - aux_output_loss: -1.3800

# %% [markdown]
# #OR

# %%
# model.compile(optimizer='rmsprop',
#               loss={'main_output': 'binary_crossentropy', 'aux_output': 'binary_crossentropy'},
#               loss_weights={'main_output': 1., 'aux_output': 0.2})

# # And trained it via:
# model.fit({'main_input': headline_data, 'aux_input': additional_data},
#           {'main_output': headline_labels, 'aux_output': additional_labels},
#           epochs=50, batch_size=32)

# %%
# predict
pred = model.predict({'main_input':headline_data,'aux_input':additional_data})
#or
# pred = model.predict([headline_data, additional_data])

print(pred)
# Out:
# [array([[0.        ],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [1.        ],
#        [0.        ],
#        [0.        ],
#        [1.        ],
#        [0.83709025],
#        [1.        ],
#        [0.        ],
#        [0.9846075 ]], dtype=float32), array([[2.6067013e-01],
#        [2.4362400e-01],
#        [2.5839195e-01],
#        [2.6405764e-01],
#        [9.3123317e-04],
#        [2.5813866e-01],
#        [2.6187634e-01],
#        [7.2118640e-04],
#        [4.5843032e-01],
#        [4.5183301e-04],
#        [2.6233160e-01],
#        [1.1338592e-03]], dtype=float32)]
