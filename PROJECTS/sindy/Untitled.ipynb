# %%
import pandas as pd
import datetime

# %%
data = pd.read_csv('./Train.csv')

# %%
data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
# data['placementDateTime'] = str(data['Placement - Day of Month'])+str(data['Placement - Weekday (Mo = 1)'])+str(data['Placement - Time'])
# data.head()
riderIds = data['Rider Id']
dir(riderIds)

# counter =0
# idToCheck = 'Rider_Id_432'
# for i,d in range(len(riderIds)):
#     if(d==idToCheck):
#         counter+=1
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
placementTime = data['Placement - Time'].to_timestamp
placementTime
# Out:
# <bound method Series.to_timestamp of 0         9:35:46 AM
# 1        11:16:16 AM
# 2        12:39:25 PM
# 3         9:25:34 AM
# 4         9:55:18 AM
#             ...
# 21196     3:54:38 PM
# 21197    10:13:34 AM
# 21198     5:06:16 PM
# 21199     9:31:39 AM
# 21200     2:19:47 PM
# Name: Placement - Time, Length: 21201, dtype: object>

# %%
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
datetime.datetime()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-498da460a6fb> in <module>
# ----> 1 datetime.datetime(2019)
#
# TypeError: function missing required argument 'month' (pos 2)

# %%
arrivalAtDestinationTime =  data['Arrival at Destination - Time']
arrivalAtDestinationTime
# Out:
# 0        10:39:55 AM
# 1        12:17:22 PM
# 2         1:00:38 PM
# 3        10:05:27 AM
# 4        10:25:37 AM
#             ...
# 21196     4:20:17 PM
# 21197    10:46:17 AM
# 21198     6:40:05 PM
# 21199    10:08:15 AM
# 21200     3:17:23 PM
# Name: Arrival at Destination - Time, Length: 21201, dtype: object

# %%
# Out:
#   File "<ipython-input-12-22bd6025e6fc>", line 1
#     new datetime
#                ^
# SyntaxError: invalid syntax
